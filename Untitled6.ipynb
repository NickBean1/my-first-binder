# %%
#hide
# ! [ -e /content ] && pip install -Uqq fastbook
import fastbook
fastbook.setup_book()

# %%
#hide
from fastbook import *
from fastai.vision.widgets import *

# %%
key = os.environ.get('AZURE_SEARCH_KEY', '093846b0f8a94f74ae2954562f8cc12e')

# %%
search_images_bing
# Out:
# <function fastbook.search_images_bing(key, term, min_sz=128, max_images=150)>

# %%
results = search_images_bing(key, 'grizzly bear')
ims = results.attrgot('contentUrl')
len(ims)
# Out:
# 150

# %%
ims = ['http://3.bp.blogspot.com/-S1scRCkI3vY/UHzV2kucsPI/AAAAAAAAA-k/YQ5UzHEm9Ss/s1600/Grizzly%2BBear%2BWildlife.jpg']

# %%
dest = 'images/grizzly.jpg'
download_url(ims[0], dest)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='704512' class='' max='697626' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.99% [704512/697626 00:00&lt;00:00]
#     </div>
# Path('images/grizzly.jpg')

# %%
im = Image.open(dest)
im.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=108x128>

# %%
bear_types = 'grizzly','black','teddy'
path = Path('bears')

# %%
if not path.exists():
    path.mkdir()
    for o in bear_types:
        dest = (path/o)
        dest.mkdir(exist_ok=True)
        results = search_images_bing(key, f'{o} bear')
        download_images(dest, urls=results.attrgot('contentUrl'))

# %%
fns = get_image_files(path)
fns
# Out:
# (#422) [Path('bears/black/00cb19c2-9885-4f19-bb4a-a0471c6e56fc.jpg'),Path('bears/black/017d15fe-e77c-4733-87e8-5b1e6d183e6f.jpg'),Path('bears/black/0180c3bb-feca-44be-a640-2bb610ef9cb6.jpg'),Path('bears/black/0351e35e-7e7f-4214-995e-4108aa88f751.jpg'),Path('bears/black/03c13ac7-6656-4c76-b76c-983300c4d40c.jpg'),Path('bears/black/03c5284e-bdf1-46b6-ac5a-703d071adbca.jpg'),Path('bears/black/05e482f6-ae11-44d7-9217-4b71bf9c230b.jpg'),Path('bears/black/0cdb32f4-2fd4-4a58-86bf-a7185faa4726.jpg'),Path('bears/black/0dd5f7ea-b819-4a9b-8870-8a10a54113c9.jpg'),Path('bears/black/0f83e601-f331-47a8-96a9-fdd1ade33678.jpg')...]

# %%
failed = verify_images(fns)
failed

# %%
failed.map(Path.unlink);

# %%
bears = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=Resize(128))

# %%
dls = bears.dataloaders(path)

# %%
dls.valid.show_batch(max_n=4, nrows=1)

# %%
bears = bears.new(item_tfms=Resize(128, ResizeMethod.Squish))
dls = bears.dataloaders(path)
dls.valid.show_batch(max_n=4, nrows=1)

# %%
bears = bears.new(item_tfms=Resize(128, ResizeMethod.Pad, pad_mode='zeros'))
dls = bears.dataloaders(path)
dls.valid.show_batch(max_n=4, nrows=1)

# %%
bears = bears.new(item_tfms=RandomResizedCrop(128, min_scale=0.3))
dls = bears.dataloaders(path)
dls.train.show_batch(max_n=4, nrows=1, unique=True)

# %%
bears = bears.new(item_tfms=Resize(128), batch_tfms=aug_transforms(mult=2))
dls = bears.dataloaders(path)
dls.train.show_batch(max_n=8, nrows=2, unique=True)

# %%
bears = bears.new(
    item_tfms=RandomResizedCrop(224, min_scale=0.5),
    batch_tfms=aug_transforms())
dls = bears.dataloaders(path)

# %%
learn = vision_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(4)
# Out:
# C:\Users\Bean\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\Bean\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.246791</td>
#       <td>0.102872</td>
#       <td>0.023810</td>
#       <td>00:56</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.210576</td>
#       <td>0.027947</td>
#       <td>0.011905</td>
#       <td>01:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.151695</td>
#       <td>0.008217</td>
#       <td>0.000000</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.112339</td>
#       <td>0.015246</td>
#       <td>0.000000</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.091292</td>
#       <td>0.014927</td>
#       <td>0.000000</td>
#       <td>00:57</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
interp.plot_top_losses(5, nrows=1)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
#hide_output
cleaner = ImageClassifierCleaner(learn)
cleaner
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# VBox(children=(Dropdown(options=('black', 'grizzly', 'teddy'), value='black'), Dropdown(options=('Train', 'Val…

# %%
learn.export()

# %%
path = Path()
path.ls(file_exts='.pkl')
# Out:
# (#1) [Path('export.pkl')]

# %%
learn_inf = load_learner(path/'export.pkl')

# %%
learn_inf.predict('images/grizzly.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('grizzly', tensor(1), tensor([2.5363e-05, 9.9988e-01, 9.0356e-05]))

# %%
learn_inf.dls.vocab
# Out:
# ['black', 'grizzly', 'teddy']

# %%
#hide_output
btn_upload = widgets.FileUpload()
btn_upload
# Out:
# FileUpload(value={}, description='Upload')

# %%
#hide
# For the book, we can't actually click an upload button, so we fake it
btn_upload = SimpleNamespace(data = ['images/grizzly.jpg'])

# %%
img = PILImage.create(btn_upload.data[-1])

# %%
#hide_output
out_pl = widgets.Output()
out_pl.clear_output()
with out_pl: display(img.to_thumb(128,128))
out_pl
# Out:
# Output()

# %%
pred,pred_idx,probs = learn_inf.predict(img)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
#hide_output
lbl_pred = widgets.Label()
lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'
lbl_pred
# Out:
# Label(value='Prediction: grizzly; Probability: 0.9999')

# %%
#hide_output
btn_run = widgets.Button(description='Classify')
btn_run
# Out:
# Button(description='Classify', style=ButtonStyle())

# %%
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_classify)

# %%
#hide
#Putting back btn_upload to a widget for next cell
btn_upload = widgets.FileUpload()

# %%
#hide_output
VBox([widgets.Label('Select your bear!'), 
      btn_upload, btn_run, out_pl, lbl_pred])
# Out:
# VBox(children=(Label(value='Select your bear!'), FileUpload(value={'schwarbaer.jpg': {'metadata': {'name': 'sc…

# %%
# !pip install voila --user
# !jupyter serverextension enable --sys-prefix voila
# Out:
# Collecting voila
#   Using cached voila-0.4.0-py3-none-any.whl (5.5 MB)
# Requirement already satisfied: traitlets<6,>=5.0.3 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from voila) (5.9.0)
# Requirement already satisfied: nbclient<0.8,>=0.4.0 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from voila) (0.7.2)
# Requirement already satisfied: websockets>=9.0 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from voila) (11.0.3)
# Requirement already satisfied: jupyter-core>=4.11.0 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from voila) (5.3.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.3.0 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from voila) (2.21.0)
# Requirement already satisfied: nbconvert<8,>=6.4.5 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from voila) (7.2.9)
# Requirement already satisfied: jupyter-client<=7.4.1,>=6.1.3 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from voila) (7.4.1)
# Requirement already satisfied: jupyter-server<2.0.0,>=1.18 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from voila) (1.24.0)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from jupyter-client<=7.4.1,>=6.1.3->voila) (25.0.2)
# Requirement already satisfied: nest-asyncio>=1.5.4 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from jupyter-client<=7.4.1,>=6.1.3->voila) (1.5.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from jupyter-client<=7.4.1,>=6.1.3->voila) (2.8.2)
# Requirement already satisfied: tornado>=6.2 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from jupyter-client<=7.4.1,>=6.1.3->voila) (6.2)
# Requirement already satisfied: entrypoints in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from jupyter-client<=7.4.1,>=6.1.3->voila) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from jupyter-core>=4.11.0->voila) (3.1.1)
# Requirement already satisfied: pywin32>=300 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from jupyter-core>=4.11.0->voila) (304)
# Requirement already satisfied: nbformat>=5.2.0 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from jupyter-server<2.0.0,>=1.18->voila) (5.8.0)
# Requirement already satisfied: pywinpty in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from jupyter-server<2.0.0,>=1.18->voila) (2.0.10)
# Requirement already satisfied: argon2-cffi in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from jupyter-server<2.0.0,>=1.18->voila) (21.3.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from jupyter-server<2.0.0,>=1.18->voila) (3.6.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from jupyter-server<2.0.0,>=1.18->voila) (0.17.0)
# Requirement already satisfied: packaging in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from jupyter-server<2.0.0,>=1.18->voila) (23.0)
# Requirement already satisfied: websocket-client in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from jupyter-server<2.0.0,>=1.18->voila) (1.5.1)
# Requirement already satisfied: jinja2 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from jupyter-server<2.0.0,>=1.18->voila) (3.1.2)
# Requirement already satisfied: Send2Trash in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from jupyter-server<2.0.0,>=1.18->voila) (1.8.0)
# Requirement already satisfied: prometheus-client in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from jupyter-server<2.0.0,>=1.18->voila) (0.16.0)
# Requirement already satisfied: jsonschema>=4.17.3 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from jupyterlab-server<3,>=2.3.0->voila) (4.17.3)
# Requirement already satisfied: json5>=0.9.0 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from jupyterlab-server<3,>=2.3.0->voila) (0.9.5)
# Requirement already satisfied: babel>=2.10 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from jupyterlab-server<3,>=2.3.0->voila) (2.12.1)
# Requirement already satisfied: requests>=2.28 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from jupyterlab-server<3,>=2.3.0->voila) (2.30.0)
# Requirement already satisfied: importlib-metadata>=4.8.3 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from jupyterlab-server<3,>=2.3.0->voila) (6.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (1.5.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (0.2.2)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (2.14.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (4.12.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (2.1.2)
# Requirement already satisfied: mistune<3,>=2.0.3 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (2.0.5)
# Requirement already satisfied: bleach in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (6.0.0)
# Requirement already satisfied: defusedxml in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (0.7.1)
# Requirement already satisfied: tinycss2 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (1.2.1)
# Requirement already satisfied: idna>=2.8 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server<2.0.0,>=1.18->voila) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server<2.0.0,>=1.18->voila) (1.3.0)
# Requirement already satisfied: pytz>=2015.7 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from babel>=2.10->jupyterlab-server<3,>=2.3.0->voila) (2022.7.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from importlib-metadata>=4.8.3->jupyterlab-server<3,>=2.3.0->voila) (3.15.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.3.0->voila) (5.12.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.3.0->voila) (0.19.3)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.3.0->voila) (1.3.10)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.3.0->voila) (22.2.0)
# Requirement already satisfied: fastjsonschema in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from nbformat>=5.2.0->jupyter-server<2.0.0,>=1.18->voila) (2.16.3)
# Requirement already satisfied: six>=1.5 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client<=7.4.1,>=6.1.3->voila) (1.16.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from requests>=2.28->jupyterlab-server<3,>=2.3.0->voila) (1.26.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from requests>=2.28->jupyterlab-server<3,>=2.3.0->voila) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from requests>=2.28->jupyterlab-server<3,>=2.3.0->voila) (2022.12.7)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from argon2-cffi->jupyter-server<2.0.0,>=1.18->voila) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from beautifulsoup4->nbconvert<8,>=6.4.5->voila) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from bleach->nbconvert<8,>=6.4.5->voila) (0.5.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<2.0.0,>=1.18->voila) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\bean\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<2.0.0,>=1.18->voila) (2.21)
# Installing collected packages: voila
# Successfully installed voila-0.4.0
#   WARNING: The script voila.exe is installed in 'C:\Users\Bean\AppData\Roaming\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Enabling: voila
# - Writing config: C:\Users\Bean\AppData\Roaming\jupyterlab-desktop\jlab_server\etc\jupyter
#     - Validating...
#       voila 0.4.0 ok

# %%
learn.export()
